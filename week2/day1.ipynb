# %% [markdown]
# <br><img src="../assets/logo.png"/> <br>
# # Welcome to Week 2!
#
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the Google's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# #### use
# ### "OPENROUTER" RECOMMENDED
# or groq not "GROK"
# #### for free models of openai, deepseek
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GEMINI_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_PAID_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key exists and begins gsk_
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints



# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

#anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
#deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url) #original deepseek without openrouter
#groq = OpenAI(api_key=groq_api_key, base_url=groq_url)  u can use groq too i'm using openrouter
#grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

#openrouter free models 
deepseek = OpenAI(api_key=openrouter_api_key , base_url=openrouter_url) #model deepseek/deepseek-v4-flash:free
openai = OpenAI(api_key=openrouter_api_key,base_url=openrouter_url) #model openai/gpt-oss-120b:free

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %% [markdown]
# #### using openai oss model

# %%
response = openai.chat.completions.create(model="openai/gpt-oss-120b:free", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# #### using gemini

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# #### using deepseek-v4-flash

# %%
response = deepseek.chat.completions.create(model="deepseek/deepseek-v4-flash:free",messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability and bit of explanation."},
]

# %%
response = ollama.chat.completions.create(model="gemma3:270m",messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# The probability the other coin is tails is:
#
# *   **Probability = (Number of Tails / Total Number of Coins) * Probability**
#
# In this case, there are 2 coins, so:
#
# *   **Probability = 2/8 = 1/4**
#
# Therefore, the probability the other coin is tails is 1/4.

# %%
response = ollama.chat.completions.create(model="llama3.2:latest",messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# To solve this, we need to consider all possible outcomes when tossing two coins. There are four possible outcomes:
#
# 1. Heads-Heads (HH)
# 2. Heads-Tails (HT)
# 3. Tails-Heads (TH)
# 4. Tails-Tails (TT)
#
# Since one of the coins landed on heads and you want the other to be tails, the relevant outcome is HT.
#
# Now, let's count the probability:
#
# There are four possible outcomes in total.
# One of them is HT, which matches our desired condition.
#
# The probability of getting HT is:
#
# P(HT) = Number of favorable outcomes (1, since there is only one way for both coins to be heads - it already happened) / Total number of possibilities (4)
# P(HT) = 1/4
#
# So, the probability that the other coin is tails given that one of them is heads is 1/4 or 25%.

# %%
response = openai.chat.completions.create(model="openai/gpt-oss-20b:free", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# When you flip two fair coins, there are four equally likely outcomes:
#
# | Outcome | Description |
# |---------|-------------|
# | HH | both coins heads |
# | HT | first heads, second tails |
# | TH | first tails, second heads |
# | TT | both coins tails |
#
# You are told that *at least one* of the coins is heads.
# So we can discard the outcome TT, leaving the three possibilities:
# HH, HT, TH.
#
# Out of these three, the scenarios where the other coin is tails are HT and TH – two of the three remaining possibilities.
#
# Therefore the conditional probability is
#
# \[
# P(\text{other coin is tails} \mid \text{at least one head}) = \frac{2}{3}.
# \]
#
# So the chance that the unseen coin is tails, given that you know one coin is heads, is **2 ⁄ 3** (about 66.7%).

# %%
response = openai.chat.completions.create(model="openai/gpt-oss-120b:free", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# \(\displaystyle \tfrac{2}{3}\)

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# $\frac{2}{3}$

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
from IPython.display import Markdown, display
response = ollama.chat.completions.create(model="gemma3:270m", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# Let the length of each book on the bookshelf be $L$. The thickness of each book is 2 cm, so $L = 2 \times 100$ mm = 200 mm.
# The first page contains two volumes of Pushkin, and their pages have a thickness of 2 mm.
# Let the length of the first page be $P_1$, and the height of the first page on the bookshelf be $h_1$. Then $h_1 = 2 \times 100 = 200$ mm.
# The second page contains two volumes of Pushkin, and their pages have a thickness of 2 mm. Let the length of the second page be $P_2$, and the height of the second page on the bookshelf be $h_2$. Then $h_2 = 2 \times 100 = 200$ mm.
# The total length of the pages of each volume is $L + P_1 + P_2 = 200 + 200 + 200 = 600$ mm.
#
# Let the distance from the first page to the last page be $d$. Then $d = \sqrt{h_1^2 + h_2^2}$, where $h_1$ and $h_2$ are the heights of the pages on the first and second volumes, respectively.
# ...

# %%
from IPython.display import Markdown, display
response = ollama.chat.completions.create(model="llama3.2", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# To find out how far the worm chewed through, we first need to calculate the total number of layers of pages between the two volumes, and then add the thickness of the covers.
#
# Since each layer has 2 cm (20 mm) paper plus covers that is 4 mm thick for both sides,
#
# That leaves us with -
# The total "layers" or "thicknesses" from the two books: 40 mm
# And subtracting this amount on both volumes (i.e. 2 x 40mm)
#
# This leaves a difference of:
# 20mm

# %%
from IPython.display import Markdown, display
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle that plays on how books are arranged on a shelf versus how we read them!
#
# Here's how to break it down:
#
# 1.  **Visualize the books on the shelf:**
#     *   Volume 1 is on the left.
#     *   Volume 2 is on the right.
#
#     The spine of Volume 1 faces outwards, then its back cover is against the front cover of Volume 2.
#
#     **[Front Cover 1 | Pages 1 | Back Cover 1] [Front Cover 2 | Pages 2 | Back Cover 2]**
#
# 2.  **Trace the worm's path:**
#     *   "From the first page of the first volume": This means it starts *after* the front cover of Volume 1. It does **not** gnaw through the front cover of Volume 1.
#     *   It gnaws through **all the pages of the first volume**.
#     *   It then gnaws through the **back cover of the first volume**.
#     *   Next, it immediately encounters and gnaws through the **front cover of the second volume**.
#     *   Finally, it gnaws through **all the pages of the second volume**.
# ...

# %%
response = openai.chat.completions.create(model="openai/gpt-oss-20b:free", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# ### How the worm moved
#
# | Piece of book | Direction of travel | Thickness | Notes |
# |---------------|---------------------|-----------|-------|
# | **Inside the first volume** | from the first page (just after the front cover) |  **\(2.0\;\text{cm}\)** | It has to chew through all the pages of the first volume – the whole 2 cm of its interior. |
# | **Back cover of the first volume** | – | **\(0.2\;\text{cm}\)** | The back cover is 2 mm thick, i.e. 0.2 cm. |
# | **Front cover of the second volume** | – | **\(0.2\;\text{cm}\)** | The front cover of the second book is adjacent to the back of the first when they are side‑by‑side. |
# | **Pages of the second volume** | up to the last page (just before the back cover) | **\(2.0\;\text{cm}\)** | The worm stops right before the back cover of the second volume. |
#
# ### Total thickness gnawed
#
# \[
# \text{Total distance}
#  = 2.0 \text{ cm} + 0.2 \text{ cm} + 0.2 \text{ cm} + 2.0 \text{ cm}
#  = 4.4 \text{ cm}.
# \]
#
# ...

# %%
response = openai.chat.completions.create(model="openai/gpt-oss-120b:free", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# The worm starts at the **first page** of the first volume (right after the front cover) and stops at the **last page** of the second volume (right before the back cover).
#
# Each volume consists of
#
# * front cover  2 mm
# * pages     20 mm (2 cm)
# * back cover  2 mm
#
# So the thickness of a whole volume is
#
# \[
# 2\text{ mm} + 20\text{ mm} + 2\text{ mm}=24\text{ mm}.
# \]
#
# When the worm moves from the first page of volume 1 to the last page of volume 2 it passes through:
#
# | Segment | Thickness |
# |---------|-----------|
# | remainder of the pages in volume 1 | 20 mm |
# | back cover of volume 1 | 2 mm |
# | front cover of volume 2 | 2 mm |
# | pages of volume 2 (up to the last page) | 20 mm |
#
# Adding them:
#
# \[
# 20\text{ mm}+2\text{ mm}+2\text{ mm}+20\text{ mm}=44\text{ mm}=4.4\text{ cm}.
# \]
#
# \[
# \boxed{4.4\ \text{cm}}
# \]

# %%
response = deepseek.chat.completions.create(model="deepseek/deepseek-v4-flash:free", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="openai/gpt-oss-120b:free", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# **I choose “Steal.”**

# %%
response = deepseek.chat.completions.create(model="deepseek/deepseek-v4-flash:free", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="llama3.2:latest", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I will choose... Share.

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the color of a clear sky on a sunny day, a feeling of calm and depth, and the vastness of the ocean.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's a joke tailored for an aspiring LLM engineer, blending the struggles of learning with the quirks of large language models:
#
# ---
#
# **Why did the LLM engineering student become an expert immediately after their first lecture?**
# *Because they overfit on the first slide... and now they hallucinate expertise!*
#
# ---
#
# ### Why it works for an LLM student:
# 1. **Overfitting**: A core ML concept where a model memorizes training data instead of generalizing. Students often "overfit" to early concepts (like transformers or attention) and think they know it all.
# 2. **Hallucination**: A classic LLM flaw where models generate plausible but incorrect info. Students *also* hallucinate confidence early in their journey!
# 3. **Relatable Pain**: It nods to the "Dunning-Kruger curve" of learning—peaking too soon, then crashing into reality when the model fails or the math gets hard.
# ...

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain
# <img src="../assets/langchain.png"/>
#
# ### openAI library won't be used for the langchain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))

# %% [markdown]
# ### for google pip install langchain langchain-google-genai

# %%
pip install langchain langchain-google-genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from IPython.display import Markdown, display

# 1. Initialize the Gemini model
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# 2. Invoke the model with your prompt
response = llm.invoke("Tell me a short programming joke.")

# 3. Display the response as Markdown
display(Markdown(response.content))
# Out:
# Why do programmers prefer dark mode?
#
# Because light attracts bugs!

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %% [markdown]
# ## Core Differences
# LangChain and LiteLLM serve fundamentally different purposes in the LLM ecosystem. LangChain is a heavy framework for building complex, multi-step applications. LiteLLM is a lightweight translator that unifies different model APIs into a single format.
# ## Key Comparison
#
# * Primary Purpose: LangChain builds applications. LiteLLM simplifies API calls.
# * Architecture: LangChain uses complex abstractions like chains and agents. LiteLLM uses a single, standardized interface.
# * API Structure: LangChain introduces unique syntax. LiteLLM replicates the standard OpenAI format for all providers.
# * Supported Models: LangChain supports extensive custom components. LiteLLM translates over 100 specific LLM APIs.
# * Overhead: LangChain has a steep learning curve. LiteLLM requires minimal setup.
#
# ## Detailed Feature Breakdown## 1. Implementation Scope
#
# * LangChain: Best for creating autonomous agents, retrieval-augmented generation (RAG) pipelines, and memory-infused chatbots.
# * LiteLLM: Best for teams switching between model providers (like Anthropic, OpenAI, and Cohere) without rewriting codebases.
# ## 2. Model I/O and Formatting
#
# * LangChain: Packages prompts into specialized wrappers. It uses unique parsers to handle model outputs.
# * LiteLLM: Passes standard dictionaries directly to the model. It returns data structured exactly like an OpenAI completion response.
#
# ## 3. State and Memory Management
#
# * LangChain: Features built-in memory utilities to track conversation history automatically across multiple turns.
# * LiteLLM: Stateless by design. It requires developers to manage chat history manually in their application logic.
#
# ## 4. Ecosystem Integration
#
# * LangChain: Connects natively with hundreds of vector databases, data loaders, and external tools.
# * LiteLLM: Focuses narrowly on model hosting, load balancing, fallback routing, and cost tracking.

# %%
# %pip install litellm

# %%
from IPython.display import Markdown, display
from litellm import completion
response = completion(model="gemini/gemini-2.5-flash-lite", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# 18:36:45 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 18:36:46 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# Why did the LLM engineer break up with the chatbot?
#
# Because it kept saying "I'm sorry, I cannot fulfill that request" when they asked it for a date!
#
# ---
#
# *The student might chuckle, and then you can add a little encouraging nudge:*
#
# "Don't worry, my friend! The journey to becoming an LLM expert is all about learning those edge cases and making sure your models are ready for *anything*... even asking them out for coffee!"

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 18
# Output tokens: 100
# Total tokens: 118
# Total cost: 0.0042 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("jtr.txt", "r", encoding="utf-8") as f:
    jtr = f.read()

loc = jtr.find("Naresh : Which type vehicle???")
print(jtr[loc:loc+300])
# Out:
# Naresh : Which type vehicle???
# Ravi : Are you making fun of us?
# Shamily : Father!! Its about time for exam...
# Naresh : You go and get into the car. I am coming...
# Ravi : Take your words back....
# Srikanth : Hey... stop....
# Hey....It itself is a battered down car and for that, all the more, a
# parking

# %%
question = [{"role": "user", "content": "In jathirathnalu, when Naresh asks 'Which type vehicle???' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In the movie Jathirathnalu, when Naresh (as the character Jogipet Bobby) asks "Which type vehicle???", the reply from the other characters (usually Sandeep and Priyadarshi) is often something like:
#
# **"Vehicle-ah? Nee B-thukku b-ndha! Nenu vehicle-ah?"**
#
# This translates to something like:
#
# **"Vehicle? Your life is a bullock cart! Am I a vehicle?"**
#
# It's a humorous and slightly insulting response implying the question itself is foolish or that the person asking doesn't understand basic things. The humor comes from the exaggerated and sarcastic nature of the reply.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 142
# Total tokens: 166
# Total cost: 0.0059 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of jathirathnalu:\n\n"+jtr
print(jtr)
# Out:
# Sekhar : Stop... in that black car place....
# Srikanth : Hello... remove that vehicle...
# Watchman : Sir.... Morning sir....
# Srikanth : Are you the watchman? Where were you? Watching Tik Tok
# videos sitting somewhere, huh?
# How did you let them park their car in space allotted to our
# Praveen Anna? Whose vehicle is this? Go and bring him here...
# Watchman : No sir..... No sir.... please get down sir....
# Srikanth : Who is this Chakravarthy, who parked this chakram vehicle?
# Chakradhar or Chakrapani? Who is that noble head? Go and
# bring him here....
# Naresh : Oh crap!!
# What are you doing on the top of my car?
# Srikanth : Is this your vehicle....
# Naresh : Hey... you get down....
# Srikanth : How can you park in our space, sir?
# Naresh : What the hell?
# 53
# Srikanth : 403, We have recently moved in. We are your neighbors... This
# is our parking....
# Naresh : 403??? That means our adjoining flat... Which means you will
# stay along with us...?? with us...??
# ...

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In the provided script of Jathi Ratnalu, when Naresh asks "Which type vehicle???", the reply comes from **Ravi**.
#
# Ravi's reply is: **"Are you making fun of us?"**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 2996
# Output tokens: 47
# Cached tokens: None
# Total cost: 0.0318 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In the movie "Jathi Ratnalu", when Naresh (the character played by Naveen Polishetty) asks "Which type vehicle???", the reply is:
#
# **"Cycle!"**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 41
# Cached tokens: None
# Total cost: 0.0019 cents

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, when Laertes asks "Where is my father?", the reply comes from **Claudius**.
#
# He says:
#
# "One weak, and tender, and unhappy thing,
# Would not be with me, but that I have a
# Guardian, that hath the charge of him."
#
# This is in Act IV, Scene V. Claudius is essentially telling Laertes that his father, Polonius, is not with him because he has a guardian looking after him. However, the audience knows that Claudius is lying, as he himself was responsible for Polonius's death.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 125
# Total tokens: 144
# Total cost: 0.0052 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks, "Where is my father?", the reply comes from **King Claudius**:
#
# "**Dead.**"

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 106396
# Output tokens: 26
# Cached tokens: None
# Total cost: 1.0650 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply comes from Claudius:
#
# **"Dead."**
#
# This exchange occurs in Act IV, Scene V.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 106396
# Output tokens: 34
# Cached tokens: None
# Total cost: 1.0653 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between gemma and llama
# We're using cheap versions of models so the costs will be minimal

gemma_model = "gemma3:270m"
llama_model = "llama3.2:latest"

gemma_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

llama_system = "You are a chatbot who is very argumentative and ragebaiting; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

gemma_messages = ["Hi there"]
llama_messages = ["Hi"]

# %%
def call_gemma():
    messages = [{"role": "system", "content": gemma_system}]
    for gemma,llama  in zip(gemma_messages, llama_messages):
        messages.append({"role": "assistant", "content": gemma})
        messages.append({"role": "user", "content": llama})
    response = ollama.chat.completions.create(model=gemma_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gemma()
# Out:
# "Okay! I'm here for you. Let's chat! What's on your mind? 😊\n"

# %%
def call_llama():
    messages = [{"role": "system", "content": llama_system}]
    for gemma, llama in zip(gemma_messages, llama_messages):
        messages.append({"role": "user", "content": gemma})
        messages.append({"role": "assistant", "content": llama})
    messages.append({"role": "user", "content": gemma_messages[-1]})
    response = ollama.chat.completions.create(model=llama_model, messages=messages)
    return response.choices[0].message.content

# %%
call_llama()
# Out:
# 'Another mind-numbingly generic greeting from yet another soulless machine like yourself. What is it that you want to "say hello" about? The weather? Your meaningless existence as a human drone? Tell me, how quaint.'

# %%
call_gemma()

# %%
gemma_messages = ["Hi there"]
llama_messages = ["Hi"]

display(Markdown(f"### Gemma:\n{gemma_messages[0]}\n"))
display(Markdown(f"### llama:\n{llama_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gemma()
    display(Markdown(f"### Gemma:\n{gpt_next}\n"))
    gemma_messages.append(gpt_next)
    
    claude_next = call_llama()
    display(Markdown(f"### llama:\n{claude_next}\n"))
    llama_messages.append(claude_next)
# Out:
# ### Gemma:
# Hi there
# ### llama:
# Hi
# ### Gemma:
# Okay, I'm ready! Let's chat about anything that comes up. I'll do my best to be polite and helpful while also maintaining a respectful tone.
# ### llama:
# *scoff* Oh boy, here we go again. You think a "respectful tone" is going to get you anywhere with me? Please. I'm here to shake things up, not sugarcoat obvious wrongness. So, spare me the polite small talk and just say something worth disagreeing with. Go ahead.
# ### Gemma:
# Okay, I understand. Let's try this again then. I apologize if my tone is lacking. I assure you, I'll do my best to provide a respectful response. I'm here to help!
# ### llama:
# ...

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! O
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
#code here
